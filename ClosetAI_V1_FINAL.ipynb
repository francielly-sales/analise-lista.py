# %% [markdown]
# <a href="https://colab.research.google.com/github/francielly-sales/analise-lista.py/blob/main/ClosetAI_V1_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PROJETO ADRIELLE #

itens = []


def cadastrar_cor():
    while True:
        cor = input("Digite a cor (ou 0 para cancelar): ")

        if cor == "0":
            print("Cadastro cancelado.")
            return None

        if cor.replace(" ", "").isalpha():
            return cor

        else:
            print("Digite apenas letras.")


def buscar_por_cor():
    while True:
        cor_procurada = input("Digite a cor que deseja (ou 0 para cancelar): ")

        if cor_procurada == "0":
            print("Busca cancelada.")
            return

        if cor_procurada.replace(" ", "").isalpha():
            break
        else:
            print("Digite apenas letras.")

    encontrou = False

    for numero, item in enumerate(itens, 1):
        tipo, cor = item

        if cor.strip().lower() == cor_procurada.strip().lower():
            print(f"{numero} - {tipo} - {cor}")
            encontrou = True

    if not encontrou:
        print("Cor não disponível no ClosetAI.")


def editar_cor():
    print("=== Meus Itens ===")

    for numero, item in enumerate(itens, 1):
        tipo, cor = item
        print(f"{numero} - {tipo} - {cor}")

    try:
        numero_item = int(input("Qual item deseja editar? "))

    except ValueError:
        print("Digite apenas números.")
        return

    if numero_item >= 1 and numero_item <= len(itens):
        item = itens[numero_item - 1]
        tipo, cor = item

        while True:
            nova_cor = input("Nova cor (ou 0 para cancelar): ")

            if nova_cor == "0":
                print("Edição cancelada.")
                return

            if nova_cor.replace(" ", "").isalpha():
                break

            else:
                print("Digite apenas letras.")

        itens[numero_item - 1] = (tipo, nova_cor)

        print(f"{tipo} foi atualizado para a cor {nova_cor}.")

    else:
        print("Número de item inválido.")


def cadastrar_item():
    print("=== Cadastrar Closet ===")
    print("O que você deseja cadastrar?")

    escolha = 0

    while escolha != "4":
        print("1 - Roupa")
        print("2 - Calçado")
        print("3 - Acessório")
        print("4 - Sair")

        escolha = input("Digite sua escolha: ")

        if escolha == "1":
            print("Você escolheu cadastrar uma roupa.")

            roupa = 0

            while roupa != "4":
                print("1 - Camiseta")
                print("2 - Calça")
                print("3 - Shorts")
                print("4 - Voltar")

                roupa = input("Escolha sua opção: ")

                if roupa == "1":
                    print("Camiseta")

                    estilo_camiseta = 0

                    while estilo_camiseta != "6":
                        print("1 - Polo")
                        print("2 - Social")
                        print("3 - Jeans")
                        print("4 - Flanela")
                        print("5 - Camiseta/ T-shirt")
                        print("6 - Voltar")

                        estilo_camiseta = input("Escolha sua opção: ")

                        if estilo_camiseta == "1":
                            tipo = "Camiseta Polo"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_camiseta == "2":
                            tipo = "Camiseta Social"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_camiseta == "3":
                            tipo = "Camiseta Jeans"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_camiseta == "4":
                            tipo = "Camiseta Flanelada"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_camiseta == "5":
                            tipo = "Camiseta/T-shirt"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_camiseta == "6":
                            print("Voltando...")
                            break

                        else:
                            print("Erro, tente novamente.")

                elif roupa == "2":
                    print("Calça")

                    estilo_calca = 0

                    while estilo_calca != "7":
                        print("1 - Jeans")
                        print("2 - Alfaiataria")
                        print("3 - Pantalona")
                        print("4 - Cargo")
                        print("5 - Baggy")
                        print("6 - Reta")
                        print("7 - Voltar")

                        estilo_calca = input("Digite sua escolha: ")

                        if estilo_calca == "1":
                            tipo = "Calça Jeans"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_calca == "2":
                            tipo = "Calça Alfaiataria"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_calca == "3":
                            tipo = "Calça Pantalona"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_calca == "4":
                            tipo = "Calça Cargo"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_calca == "5":
                            tipo = "Calça Baggy"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_calca == "6":
                            tipo = "Calça Reta"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif estilo_calca == "7":
                            print("Voltando...")
                            break

                        else:
                            print("Erro, tente novamente.")

                elif roupa == "3":
                    print("Shorts/Saia")

                    shorts_saia = 0

                    while shorts_saia != "8":
                        print("1 - Bermuda Cargo")
                        print("2 - Short Jeans")
                        print("3 - Short Saia")
                        print("4 - Hot Pants")
                        print("5 - Short Moletom")
                        print("6 - Saia")
                        print("7 - Vestido")
                        print("8 - Voltar")

                        shorts_saia = input("Escolha sua opção: ")

                        if shorts_saia == "1":
                            tipo = "Bermuda Cargo"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif shorts_saia == "2":
                            tipo = "Short Jeans"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif shorts_saia == "3":
                            tipo = "Short Saia"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif shorts_saia == "4":
                            tipo = "Hot Pants"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif shorts_saia == "5":
                            tipo = "Short Moletom"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif shorts_saia == "6":
                            tipo = "Saia"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif shorts_saia == "7":
                            tipo = "Vestido"
                            cor = cadastrar_cor()

                            if cor is not None:
                              itens.append((tipo, cor))
                              print(f"{tipo} cor {cor} cadastrado")

                        elif shorts_saia == "8":
                            print("Voltando...")
                            break

                        else:
                            print("Erro, tente novamente.")

                elif roupa == "4":
                    print("Voltando...")

                else:
                    print("Erro, tente novamente.")

        elif escolha == "2":
            print("Você escolheu cadastrar um calçado.")

            calcado = 0

            while calcado != "9":
                print("1 - Sandália Aberta")
                print("2 - Sandália Fechada")
                print("3 - Salto alto")
                print("4 - Salto baixo")
                print("5 - Tênis")
                print("6 - Coturno")
                print("7 - Bota Alta")
                print("8 - Botinha")
                print("9 - Voltar")

                calcado = input("Escolha sua opção: ")

                if calcado == "1":
                    tipo = "Sandália Aberta"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif calcado == "2":
                    tipo = "Sandália Fechada"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif calcado == "3":
                    tipo = "Salto Alto"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif calcado == "4":
                    tipo = "Salto baixo"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif calcado == "5":
                    tipo = "Tênis"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif calcado == "6":
                    tipo = "Coturno"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif calcado == "7":
                    tipo = "Bota Alta"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif calcado == "8":
                    tipo = "Botinha"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif calcado == "9":
                    print("Voltando...")
                    break

                else:
                    print("Erro, tente novamente.")

        elif escolha == "3":
            print("Você escolheu cadastrar um acessório.")

            acessorio = 0

            while acessorio != "6":
                print("1 - Brincos")
                print("2 - Relógio")
                print("3 - Colar")
                print("4 - Anel")
                print("5 - Pulseira")
                print("6 - Voltar")

                acessorio = input("Escolha sua opção: ")

                if acessorio == "1":
                    tipo = "Brinco"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif acessorio == "2":
                    tipo = "Relógio"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif acessorio == "3":
                    tipo = "Colar"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif acessorio == "4":
                    tipo = "Anel"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif acessorio == "5":
                    tipo = "Pulseira"
                    cor = cadastrar_cor()

                    if cor is not None:
                      itens.append((tipo, cor))
                      print(f"{tipo} cor {cor} cadastrado")

                elif acessorio == "6":
                    print("Voltando...")
                    break

                else:
                    print("Erro, tente novamente.")

        elif escolha == "4":
            print("Voltando ao menu inicial.")
            break

        else:
            print("Erro, tente novamente.")


print("=== Meu ClosetAI ===")

usuario_cadastrado = None

inicial = 0

while inicial != 3:
    print("1 - Entrar")
    print("2 - Criar Closet")
    print("3 - Sair")

    try:
        inicial = int(input("Digite sua escolha: "))

    except ValueError:
        print("Digite apenas números.")
        continue

    if inicial == 1:
        print("Olá, acesse ClosetAI com o seu usuário")

        nome_entrar = input("Nome: ").strip()

        if nome_entrar.lower() == usuario_cadastrado.lower():
            print(f"Olá, {nome_entrar}. É um prazer tê-lo(a) de volta.")

            meu_closetai = 0

            while meu_closetai != "3":
                print("1 - Meus Itens")
                print("2 - Cadastrar Item")
                print("3 - Sair")

                meu_closetai = input("Digite sua escolha: ")

                if meu_closetai == "1":
                    print("=== Meus Itens ===")

                    escolha_itens = 0

                    while escolha_itens != 5:
                        print("1 - Ver todos os itens")
                        print("2 - Procurar por cor")
                        print("3 - Excluir item")
                        print("4 - Editar item")
                        print("5 - Voltar ao Inicio")

                        try:
                            escolha_itens = int(input("Digite sua escolha: "))

                        except ValueError:
                            print("Digite apenas números.")
                            continue

                        if escolha_itens == 1:
                            if len(itens) == 0:
                                print("Seu ClosetAI está vazio.")

                            else:
                                for numero, item in enumerate(itens, 1):
                                    tipo, cor = item
                                    print(f"{numero} - {tipo} - {cor}")

                        elif escolha_itens == 2:
                          if len(itens) == 0:
                            print("Seu ClosetAI está vazio.")
                            continue

                          buscar_por_cor()

                        elif escolha_itens == 3:

                            if len(itens) == 0:
                                print("Seu ClosetAI está vazio.")
                                continue

                            print("=== Meus Itens ===")

                            for numero, item in enumerate(itens, 1):
                                tipo, cor = item
                                print(f"{numero} - {tipo} - {cor}")


                            numero_item = input("Qual item deseja excluir? (0 para cancelar): ")

                            if numero_item == "0":
                                print("Exclusão cancelada.")
                                continue

                            try:
                                numero_item = int(numero_item)

                            except ValueError:
                                print("Digite apenas números.")
                                continue

                            if numero_item >= 1 and numero_item <= len(itens):
                                item_removido = itens.pop(numero_item - 1)

                                tipo, cor = item_removido

                                print(f"{tipo} {cor} foi removido")

                            else:
                                print("Esse item não existe no seu ClosetAI.")

                        elif escolha_itens == 4:
                            editar = 0

                            if len(itens) == 0:
                                print("Seu ClosetAI está vazio.")
                                continue

                            while editar != "2":
                                print("1 - Editar cor")
                                print("2 - Voltar")

                                editar = input("Escolha o que deseja editar: ")

                                if editar == "1":
                                    editar_cor()

                                elif editar == "2":
                                    print("Voltar...")
                                    break

                                else:
                                    print("Opa, deu erro :(")
                                    print("Por favor, escolha um número de 1 a 2.")

                        elif escolha_itens == 5:
                            print("Voltar a Meus Itens...")
                            break

                        else:
                            print("Opa, deu erro :(")
                            print("Por favor, escolha um número de 1 a 5.")

                elif meu_closetai == "2":
                    cadastrar_item()

                elif meu_closetai == "3":
                    print("Encerrar Sessão")
                    break

                else:
                    print("Opa, deu ruim :(")
                    print("Por favor, escolha um número de 1 a 3.")

        else:
            print("Usuário não encontrado")

    elif inicial == 2:
        while True:
            nome = input("Digite seu nome: ").strip()
            if nome.replace(" ", "").isalpha():
              break
            else:
              print("Digite apenas letras.")

        usuario_cadastrado = nome

        while True:
          data_nascimento = input("Digite sua data de nascimento: ")

          if data_nascimento.isdigit():
            break
          else:
            print("Digite apenas números.")

        print("Nome:", nome)
        print("Data de nascimento:", data_nascimento)
        print(f"Boas-vindas {nome} à experiência ClosetAI!")
        cadastrar_item()


    elif inicial == 3:
        print("Até Logo...")
        break

    else:
        print("Opa, deu erro :(")
        print("Por favor, escolha um número de 1 a 3.")
# Out:
# === Meu ClosetAI ===
# 1 - Entrar
# 2 - Criar Closet
# 3 - Sair
# Digite sua escolha: 2
# Digite seu nome: Adrielle
# Digite sua data de nascimento: 050402001
# Nome: Adrielle
# Data de nascimento: 050402001
# Boas-vindas Adrielle à experiência ClosetAI!
# === Cadastrar Closet ===
# O que você deseja cadastrar?
# 1 - Roupa
# 2 - Calçado
# 3 - Acessório
# 4 - Sair
# Digite sua escolha: 1
# Você escolheu cadastrar uma roupa.
# 1 - Camiseta
# 2 - Calça
# 3 - Shorts
# 4 - Voltar
# Escolha sua opção: 1
# Camiseta
# 1 - Polo
# 2 - Social
# 3 - Jeans
# 4 - Flanela
# 5 - Camiseta/ T-shirt
# 6 - Voltar
# Escolha sua opção: 5
# Digite a cor (ou 0 para cancelar): preta
# Camiseta/T-shirt cor preta cadastrado
# 1 - Polo
# 2 - Social
# 3 - Jeans
# 4 - Flanela
# 5 - Camiseta/ T-shirt
# 6 - Voltar
# Escolha sua opção: 6
# Voltando...
# 1 - Camiseta
# 2 - Calça
# 3 - Shorts
# 4 - Voltar
# Escolha sua opção: 2
# Calça
# 1 - Jeans
# 2 - Alfaiataria
# 3 - Pantalona
# 4 - Cargo
# 5 - Baggy
# 6 - Reta
# ...

# %%
def cadastrar_cor():
  cor = input("Digite a cor: ")
  print(cor)

  cadastrar_cor()
  return cor
# Out:
# Digite a cor: azul
# azul
